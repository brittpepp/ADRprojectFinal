# %%
import pandas as pd
from os import listdir
listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Assignments.ipynb',
#  'biomarker_data.csv',
#  'DEMO22Q1.txt',
#  'DEMO22Q2.txt',
#  'DEMO22Q3.txt',
#  'DEMO22Q4.txt',
#  'DEMO23Q1.txt',
#  'DEMO23Q2.txt',
#  'DEMO23Q3.txt',
#  'DEMO23Q4.txt',
#  'DRUG22Q1.txt',
#  'DRUG22Q2.txt',
#  'DRUG22Q3.txt',
#  'DRUG22Q4.txt',
#  'DRUG23Q1.txt',
#  'DRUG23Q2.txt',
#  'DRUG23Q3.txt',
#  'DRUG23Q4.txt',
#  'DrugsFDA FDA-Approved Drugs.xlsx',
#  'Drug_BiomarkerCSV.csv',
#  'Fasta_file_parser.ipynb',
#  'feb26.ipynb',
#  'feb28.ipynb',
#  'In class',
#  'January 31.ipynb',
#  'montecarlo.ipynb',
#  'nematostella_data.csv',
#  'Project_1.ipynb',
#  'Project_Part2.ipynb',
#  'Race_ADR.csv',
#  'scenario1_otus_pandas.txt',
#  'squirrel_tail_fluffiness_vs_id.csv',
#  'squirrel_tail_length_vs_id.csv',
#  'Streptomyces_albus.ffn',
#  'Untitled.ipynb']

# %%
try:
    df = pd.read_csv('Drug_BiomarkerCSV.csv', encoding='latin1')
except UnicodeDecodeError:
    df = pd.read_csv('Drug_BiomarkerCSV.csv')
print(df.head())
df
# Out:
#               Drug               Biomarker
# 0         Abacavir                   HLA-B
# 1  Abemaciclib (1)  ESR (Hormone Receptor)
# 2  Abemaciclib (2)            ERBB2 (HER2)
# 3  Abemaciclib (3)                   MKI67
# 4      Abrocitinib                 CYP2C19
#                  Drug               Biomarker
# 0            Abacavir                   HLA-B
# 1     Abemaciclib (1)  ESR (Hormone Receptor)
# 2     Abemaciclib (2)            ERBB2 (HER2)
# 3     Abemaciclib (3)                   MKI67
# 4         Abrocitinib                 CYP2C19
# ..                ...                     ...
# 588      Warfarin (4)                    PROC
# 589  Zanubrutinib (1)                   MYD88
# 590  Zanubrutinib (2)        Chromosome 17p
# 591  Zanubrutinib (3)                TP53
# 592        Zilucoplan                    ACHR
#
# [593 rows x 2 columns]

# %%
print(df.columns)
# Out:
# Index(['Drug', 'Biomarker'], dtype='object')

# %%
drugq4_df = pd.read_csv("DRUG23Q4.txt",sep="$")
drugq4_df = drugq4_df.set_index("primaryid")

# %%
demographicq4_df = pd.read_csv("DEMO23Q4.txt",sep="$")
demographicq4_df = demographicq4_df.set_index("primaryid")
# Out:
# C:\Users\britt\AppData\Local\Temp\ipykernel_1564\2590756778.py:1: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographicq4_df = pd.read_csv("DEMO23Q4.txt",sep="$")

# %%
drugq4_df.join(demographicq4_df,how="outer",lsuffix="_drug_table",rsuffix="_demographic_table")
# Out:
#              caseid_drug_table  drug_seq role_cod  \
# primaryid
# 41505155               4150515         1       PS
# 41505155               4150515         2       SS
# 41505155               4150515         3       SS
# 41505155               4150515         4       SS
# 41505155               4150515         5        C
# ...                        ...       ...      ...
# 19454468104           19454468       183       SS
# 19454468104           19454468       184       SS
# 19454468104           19454468       185        C
# 19454468104           19454468       186        C
# 19454468104           19454468       187        C
#
#                                         drugname  \
# primaryid
# 41505155                               EFAVIRENZ
# 41505155                               TENOFOVIR
# 41505155                     LOPINAVIR\RITONAVIR
# 41505155                              LAMIVUDINE
# 41505155                             FENOFIBRATE
# ...

# %%
drugq3_df = pd.read_csv("DRUG23Q3.txt",sep="$")
drugq3_df = drugq3_df.set_index("primaryid")

# %%
demographicq3_df = pd.read_csv("DEMO23Q3.txt",sep="$")
demographicq3_df = demographicq3_df.set_index("primaryid")
# Out:
# C:\Users\britt\AppData\Local\Temp\ipykernel_1564\929129331.py:1: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographicq3_df = pd.read_csv("DEMO23Q3.txt",sep="$")

# %%
drugq3_df.join(demographicq3_df,how="outer",lsuffix="_drug_table",rsuffix="_demographic_table")
# Out:
#             caseid_drug_table  drug_seq role_cod  \
# primaryid
# 40815623              4081562         1       SS
# 40815623              4081562         2       SS
# 40815623              4081562         3       SS
# 40815623              4081562         4       SS
# 40815623              4081562         5       PS
# ...                       ...       ...      ...
# 2282718711           22827187         9        C
# 2282718711           22827187        10        C
# 2282718711           22827187        11        C
# 2282718711           22827187        12        C
# 2282718711           22827187        13        C
#
#                                      drugname  \
# primaryid
# 40815623                             ACTRAPID
# 40815623                             ACTRAPID
# 40815623    AMOXICILLIN\CLAVULANATE POTASSIUM
# 40815623                            LACTULOSE
# 40815623                           CLONAZEPAM
# ...                                       ...
# ...

# %%
drugq2_df = pd.read_csv("DRUG23Q2.txt",sep="$")
drugq2_df = drugq2_df.set_index("primaryid")

# %%
demographicq2_df = pd.read_csv("DEMO23Q2.txt",sep="$")
demographicq2_df = demographicq2_df.set_index("primaryid")
# Out:
# C:\Users\britt\AppData\Local\Temp\ipykernel_1564\3456419508.py:1: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographicq2_df = pd.read_csv("DEMO23Q2.txt",sep="$")

# %%
drugq2_df.join(demographicq2_df,how="outer",lsuffix="_drug_table",rsuffix="_demographic_table")
# Out:
#             caseid_drug_table  drug_seq role_cod               drugname  \
# primaryid
# 37318572              3731857         1       PS           CYCLOSPORINE
# 37318572              3731857         2       SS           CYCLOSPORINE
# 37318572              3731857         3       SS  MYCOPHENOLATE MOFETIL
# 37318572              3731857         4       SS  MYCOPHENOLATE MOFETIL
# 37318572              3731857         5       SS             PREDNISONE
# ...                       ...       ...      ...                    ...
# 2232317410           22323174        11       SS             VENETOCLAX
# 2234983610           22349836         1       PS                REPATHA
# 2234983610           22349836         2       SS                REPATHA
# 2234983610           22349836         3       SS                REPATHA
# 2234983610           22349836         4       SS                REPATHA
#
#                           prod_ai  val_vbm    route             dose_vbm  \
# primaryid
# ...

# %%
drugq1_df = pd.read_csv("DRUG23Q1.txt",sep="$")
drugq1_df = drugq1_df.set_index("primaryid")

# %%
demographicq1_df = pd.read_csv("DEMO23Q1.txt",sep="$")
demographicq1_df = demographicq1_df.set_index("primaryid")
# Out:
# C:\Users\britt\AppData\Local\Temp\ipykernel_1564\1033207996.py:1: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographicq1_df = pd.read_csv("DEMO23Q1.txt",sep="$")

# %%
drugq1_df.join(demographicq1_df,how="outer",lsuffix="_drug_table",rsuffix="_demographic_table")
# Out:
#              caseid_drug_table  drug_seq role_cod           drugname  \
# primaryid
# 37145755               3714575         1       PS            GLEEVEC
# 37306584               3730658         1       PS            GLEEVEC
# 37306584               3730658         2       SS            GLEEVEC
# 37370543               3737054         1       PS  IMATINIB MESYLATE
# 37370543               3737054         2       SS  IMATINIB MESYLATE
# ...                        ...       ...      ...                ...
# 22018293255           22018293         8        I      CIPROFLOXACIN
# 22018293255           22018293         9        I      CIPROFLOXACIN
# 22018293255           22018293        10       SS       NIFUROXAZIDE
# 22018293255           22018293        11        I         OLANZAPINE
# 22018293255           22018293        12        I           ITOPRIDE
#
#                        prod_ai  val_vbm    route                 dose_vbm  \
# primaryid
# ...

# %%
drug_names_df = set(df['Drug'])
drug_names_drugq4_df = set(drugq4_df['drugname'])
common_drug_names = drug_names_df.intersection(drug_names_drugq4_df)

print("Common drug names:", common_drug_names)
# Out:
# Common drug names: set()

# %%
drug_names_df = set(df['Drug'])
drug_names_drugq3_df = set(drugq3_df['drugname'])
common_drug_names = drug_names_df.intersection(drug_names_drugq3_df)

print("Common drug names:", common_drug_names)
# Out:
# Common drug names: set()

# %%
drug_names_df = set(df['Drug'])
drug_names_drugq2_df = set(drugq2_df['drugname'])
common_drug_names = drug_names_df.intersection(drug_names_drugq2_df)

print("Common drug names:", common_drug_names)
# Out:
# Common drug names: set()

# %%
drug_names_df = set(df['Drug'])
drug_names_drugq1_df = set(drugq1_df['drugname'])
common_drug_names = drug_names_df.intersection(drug_names_drugq1_df)

print("Common drug names:", common_drug_names)
# Out:
# Common drug names: set()

# %%
drug22q4_df = pd.read_csv("DRUG22Q4.txt",sep="$")
drug22q4_df = drug22q4_df.set_index("primaryid")
demographic22q4_df = pd.read_csv("DEMO22Q4.txt",sep="$")
demographic22q4_df = demographic22q4_df.set_index("primaryid")
drug_names_df = set(df['Drug'])
drug_names_drug22q4_df = set(drug22q4_df['drugname'])
common_drug_names = drug_names_df.intersection(drug_names_drug22q4_df)

print("Common drug names:", common_drug_names)
# Out:
# C:\Users\britt\AppData\Local\Temp\ipykernel_1564\1991251540.py:3: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographic22q4_df = pd.read_csv("DEMO22Q4.txt",sep="$")
# Common drug names: set()

# %%
drug22q4_df.join(demographic22q4_df,how="outer",lsuffix="_drug_table",rsuffix="_demographic_table")
# Out:
#             caseid_drug_table  drug_seq role_cod  \
# primaryid
# 58182933              5818293         1       PS
# 58965853              5896585         1       PS
# 58965853              5896585         2        I
# 58965853              5896585         3       SS
# 58965853              5896585         4       SS
# ...                       ...       ...      ...
# 2176548511           21765485        30        C
# 2176548511           21765485        31       SS
# 2176548511           21765485        32       SS
# 2176548511           21765485        33       SS
# 2176548511           21765485        34       SS
#
#                                   drugname                         prod_ai  \
# primaryid
# 58182933                         IBUPROFEN                       IBUPROFEN
# 58965853                     METRONIDAZOLE                   METRONIDAZOLE
# 58965853                     METRONIDAZOLE                   METRONIDAZOLE
# ...

# %%
drug22q3_df = pd.read_csv("DRUG22Q3.txt",sep="$")
drug22q3_df = drug22q3_df.set_index("primaryid")
demographic22q3_df = pd.read_csv("DEMO22Q3.txt",sep="$")
demographic22q3_df = demographic22q3_df.set_index("primaryid")
drug_names_df = set(df['Drug'])
drug_names_drug22q3_df = set(drug22q3_df['drugname'])
common_drug_names = drug_names_df.intersection(drug_names_drug22q3_df)

print("Common drug names:", common_drug_names)
# Out:
# C:\Users\britt\AppData\Local\Temp\ipykernel_1564\1409653124.py:3: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographic22q3_df = pd.read_csv("DEMO22Q3.txt",sep="$")
# Common drug names: set()

# %%
drug22q3_df.join(demographic22q3_df,how="outer",lsuffix="_drug_table",rsuffix="_demographic_table")
# Out:
#             caseid_drug_table  drug_seq role_cod  \
# primaryid
# 40887034              4088703         1       PS
# 40887034              4088703         2       SS
# 41438017              4143801         1       PS
# 41438017              4143801         2       SS
# 41438017              4143801         3       SS
# ...                       ...       ...      ...
# 2127031411           21270314        10        C
# 2127031411           21270314        11        C
# 2127031411           21270314        12        C
# 2127031411           21270314        13        C
# 2127031411           21270314        14       SS
#
#                                            drugname                prod_ai  \
# primaryid
# 40887034                                 LAMIVUDINE             LAMIVUDINE
# 40887034                                   CELLCEPT  MYCOPHENOLATE MOFETIL
# 41438017                                   VOLTAREN      DICLOFENAC SODIUM
# ...

# %%
drug22q2_df = pd.read_csv("DRUG22Q2.txt",sep="$")
drug22q2_df = drug22q2_df.set_index("primaryid")
demographic22q2_df = pd.read_csv("DEMO22Q2.txt",sep="$")
demographic22q2_df = demographic22q2_df.set_index("primaryid")
drug_names_df = set(df['Drug'])
drug_names_drug22q2_df = set(drug22q2_df['drugname'])
common_drug_names = drug_names_df.intersection(drug_names_drug22q2_df)

print("Common drug names:", common_drug_names)
# Out:
# C:\Users\britt\AppData\Local\Temp\ipykernel_1564\991669139.py:3: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographic22q2_df = pd.read_csv("DEMO22Q2.txt",sep="$")
# Common drug names: set()

# %%
drug22q1_df = pd.read_csv("DRUG22Q4.txt",sep="$")
drug22q1_df = drug22q1_df.set_index("primaryid")
demographic22q1_df = pd.read_csv("DEMO22Q1.txt",sep="$")
demographic22q1_df = demographic22q1_df.set_index("primaryid")
drug_names_df = set(df['Drug'])
drug_names_drug22q1_df = set(drug22q1_df['drugname'])
common_drug_names = drug_names_df.intersection(drug_names_drug22q1_df)

print("Common drug names:", common_drug_names)
# Out:
# C:\Users\britt\AppData\Local\Temp\ipykernel_1564\2735400724.py:3: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   demographic22q1_df = pd.read_csv("DEMO22Q1.txt",sep="$")
# Common drug names: set()
